# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/MyDrive/UVCE_6th_sem/Mini_Project/New_dataset/my_dataset.zip" -d "/content/dataset"
# Out:
# Archive:  /content/drive/MyDrive/UVCE_6th_sem/Mini_Project/New_dataset/my_dataset.zip
#    creating: /content/dataset/fake/
#    creating: /content/dataset/real/
#   inflating: /content/dataset/fake/AI_LD_impressionism_3-37728932-131406.jpg
#   inflating: /content/dataset/fake/AI_SD_post_impressionism_4-724011451-299701.jpg
#   inflating: /content/dataset/fake/AI_LD_art_nouveau_0-930094310-530955.jpg
#   inflating: /content/dataset/fake/AI_LD_impressionism_3-856380903-902569.jpg
#   inflating: /content/dataset/fake/AI_LD_renaissance_6-428438085-105790.jpg
#   inflating: /content/dataset/fake/AI_SD_art_nouveau_0-830511969-775886.jpg
#   inflating: /content/dataset/fake/AI_SD_romanticism_7-613557202-637812.jpg
#   inflating: /content/dataset/fake/AI_LD_realism_5-675950871-940612.jpg
#   inflating: /content/dataset/fake/AI_SD_impressionism_3-591301754-683376.jpg
#   inflating: /content/dataset/fake/AI_LD_realism_5-937269822-589036.jpg
# ...

# %%
import os
print(len(os.listdir("/content/dataset/real")))
print(len(os.listdir("/content/dataset/fake")))
# Out:
# 2500
# 2250

# %%
# !python train_ai_artbench.py
# Out:
# 2026-04-12 11:42:41.687304: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775994161.724242   11765 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775994161.735722   11765 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775994161.764416   11765 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
